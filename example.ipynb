# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

from ssa import ssa as ssa_simple
from ssa import overlap_ssa
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ts = pd.read_csv('AirPassengers.csv', parse_dates=True, index_col='Month')
print('N: ', len(ts))
ts.plot()
# Out:
# N:  144

# %%
s = overlap_ssa(ts.iloc[:, 0], n_windows=5, n_components=1)
# Out:
# s_win_size: 28, b_win_size: 84 m: 56
# embedding_dimension is automatically set to  18
# embedding_dimension is automatically set to  18
# embedding_dimension is automatically set to  18
# embedding_dimension is automatically set to  14
# embedding_dimension is automatically set to  10

# %%
fig, ax = plt.subplots()
s.plot(ax=ax)
ts.plot(ax=ax)
